# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style
sns.set(style="whitegrid")

# %%
# ------------------------------------------
# 2. Severity Distribution
# ------------------------------------------
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x="severity")
plt.title("Distribution of Bug Severity")
plt.xlabel("Severity Level")
plt.ylabel("Number of Bugs")
plt.show()

# %%
# ------------------------------------------
# 3. Missing Values Visualization
# ------------------------------------------
plt.figure(figsize=(10, 4))
df.isnull().sum().plot(kind="bar")
plt.title("Missing Values per Column")
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.xticks(rotation=45)
plt.show()

# %%
# ------------------------------------------
# 4. Bug Category vs Severity
# ------------------------------------------
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="bug_category", hue="severity")
plt.title("Bug Category vs Severity")
plt.xlabel("Bug Category")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.legend(title="Severity")
plt.show()

# %%
# ------------------------------------------
# 5. Text Length Analysis of Description
# ------------------------------------------
# Create a new column for description length
df["description_length"] = df["description"].astype(str).apply(len)

plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x="severity", y="description_length")
plt.title("Description Length vs Severity")
plt.xlabel("Severity Level")
plt.ylabel("Description Length (characters)")
plt.show()
